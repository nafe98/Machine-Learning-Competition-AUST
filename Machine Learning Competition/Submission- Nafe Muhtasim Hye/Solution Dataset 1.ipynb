# %% [markdown]
# # Importing Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('insight_001.csv')

# %% [markdown]
# # Data Information and Cleaning

# %%
df.shape
# Out:
# (12, 1226)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Columns: 1226 entries, Date to Weekly Total web site click count per Page by age and gender - UNKNOWN.U
# dtypes: float64(822), int64(403), object(1)
# memory usage: 115.1+ KB

# %%
df.shape
# Out:
# (12, 1226)

# %%
df.drop(columns=df.columns[((df==0).mean()==1)],axis=1, inplace =True)

# %%
df.shape
# Out:
# (12, 971)

# %%
df.drop(columns=df.columns[((df==0).mean() >.70)],axis=1, inplace =True)

# %%
df.dropna(axis="columns",how="any", inplace =True)

# %%
df.shape
# Out:
# (12, 143)

# %%
df.head()
# Out:
#        Date  Lifetime Total Likes  Daily Page Engaged Users  \
# 0  02-07-21                  9239                        29
# 1  02-08-21                  9241                        22
# 2  02-09-21                  9241                        91
# 3  02-10-21                  9243                        19
# 4  02-11-21                  9242                        11
#
#    Weekly Page Engaged Users  28 Days Page Engaged Users  Daily Total Reach  \
# 0                        928                        4219                921
# 1                        872                        4046                556
# 2                        584                        3954               2240
# 3                        473                        3294                616
# 4                        455                        3090                443
#
#    Weekly Total Reach  28 Days Total Reach  Daily Organic Reach  \
# 0                8867                31929                  918
# ...

# %%
print(df.isnull().sum())
# Out:
# Date                                                                         0
# Lifetime Total Likes                                                         0
# Daily Page Engaged Users                                                     0
# Weekly Page Engaged Users                                                    0
# 28 Days Page Engaged Users                                                   0
#                                                                             ..
# 28 Days Positive Feedback From Users - like.1                                0
# 28 Days Positive Feedback From Users - link.1                                0
# 28 Days Positive Feedback From Users - other.1                               0
# Weekly Total get direction click count per Page by site - WWW                0
# Weekly Total get direction click count per Page by age and gender - 65+.M    0
# Length: 143, dtype: int64

# %%
df.describe()
# Out:
#        Lifetime Total Likes  Daily Page Engaged Users  \
# count             12.000000                 12.000000
# mean            9280.083333                103.833333
# std               40.612265                100.232306
# min             9239.000000                 11.000000
# 25%             9241.750000                 21.250000
# 50%             9274.500000                 73.500000
# 75%             9313.500000                166.250000
# max             9343.000000                341.000000
#
#        Weekly Page Engaged Users  28 Days Page Engaged Users  \
# count                  12.000000                   12.000000
# mean                  684.750000                 2657.333333
# std                   198.068457                 1041.087834
# min                   448.000000                 1659.000000
# 25%                   468.500000                 1724.750000
# 50%                   690.500000                 2369.500000
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of         Date  Lifetime Total Likes  Daily Page Engaged Users  \
# 0   02-07-21                  9239                        29
# 1   02-08-21                  9241                        22
# 2   02-09-21                  9241                        91
# 3   02-10-21                  9243                        19
# 4   02-11-21                  9242                        11
# 5   02-12-21                  9249                        17
# 6   03-01-21                  9300                       138
# 7   03-02-21                  9308                       341
# 8   03-03-21                  9312                       185
# 9   03-04-21                  9318                       173
# 10  03-05-21                  9325                       164
# 11  03-06-21                  9343                        56
#
#     Weekly Page Engaged Users  28 Days Page Engaged Users  Daily Total Reach  \
# ...

# %% [markdown]
# # PROCESSING DATE DATA

# %%
df["Date"] = pd.to_datetime(df["Date"] , format = "%m-%d-%y")

# %%
df["Date"].dt.day_name()
# Out:
# 0        Sunday
# 1        Monday
# 2       Tuesday
# 3     Wednesday
# 4      Thursday
# 5        Friday
# 6        Monday
# 7       Tuesday
# 8     Wednesday
# 9      Thursday
# 10       Friday
# 11     Saturday
# Name: Date, dtype: object

# %%
df ["Day"] = df["Date"].dt.day_name()

# %%
df
# Out:
#          Date  Lifetime Total Likes  Daily Page Engaged Users  \
# 0  2021-02-07                  9239                        29
# 1  2021-02-08                  9241                        22
# 2  2021-02-09                  9241                        91
# 3  2021-02-10                  9243                        19
# 4  2021-02-11                  9242                        11
# 5  2021-02-12                  9249                        17
# 6  2021-03-01                  9300                       138
# 7  2021-03-02                  9308                       341
# 8  2021-03-03                  9312                       185
# 9  2021-03-04                  9318                       173
# 10 2021-03-05                  9325                       164
# 11 2021-03-06                  9343                        56
#
#     Weekly Page Engaged Users  28 Days Page Engaged Users  Daily Total Reach  \
# 0                         928                        4219                921
# ...

# %%
df.sort_values(by = "Date", ascending = True, inplace = True)

# %% [markdown]
# # Exploratory Data Analysis(EDA)  and Correlations finding

# %%
df.corr()
# Out:
#                                                     Lifetime Total Likes  \
# Lifetime Total Likes                                            1.000000
# Daily Page Engaged Users                                        0.633405
# Weekly Page Engaged Users                                       0.400787
# 28 Days Page Engaged Users                                     -0.921011
# Daily Total Reach                                               0.676491
# ...                                                                  ...
# 28 Days Positive Feedback From Users - like.1                  -0.944789
# 28 Days Positive Feedback From Users - link.1                  -0.121311
# 28 Days Positive Feedback From Users - other.1                 -0.926313
# Weekly Total get direction click count per Page...              0.966568
# Weekly Total get direction click count per Page...              0.966568
#
#                                                     Daily Page Engaged Users  \
# ...

# %%
import seaborn as sn
plt.figure(figsize=(15, 15))
sn.heatmap(df.corr(), annot=True)
plt.show()

# %%
plt.figure(figsize=(8,5))

plt.title('', fontdict={'fontweight':'bold', 'fontsize': 18})

plt.plot(df["Date"], df["Daily Total Reach"], 'b.-')


plt.xlabel('Date')
plt.ylabel('Daily Total Reach')

plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(8,5))

plt.title('', fontdict={'fontweight':'bold', 'fontsize': 18})

plt.plot(df["Date"], df["Daily Page Engaged Users"], 'r.-')


plt.xlabel('Date')
plt.ylabel('Daily Page Engaged Users')

plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(8,5))

plt.title('', fontdict={'fontweight':'bold', 'fontsize': 18})

plt.plot(df["Date"], df["Lifetime Total Likes"], 'r.-')


plt.xlabel('Date')
plt.ylabel('Lifetime Total Likess')

plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(8,5))

plt.title('', fontdict={'fontweight':'bold', 'fontsize': 18})

plt.plot(df["Day"], df["Lifetime Total Likes"], 'r.-')


plt.xlabel('Day')
plt.ylabel('Lifetime Total Likess')

plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(8,5))

plt.title('', fontdict={'fontweight':'bold', 'fontsize': 18})

plt.plot(df["Day"], df["Daily Page Engaged Users"], 'b.-')


plt.xlabel('Day')
plt.ylabel('Daily Page Engaged Users')

plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # Results and Findings

# %% [markdown]
# 1. Total reach has been dropped in recently
#
#
# 2. User Engagement has been dropped in recently
#
#
# 3. Satureday has the most reach
#
#
# 4. Tuesday has the most engaged Users
#
#
# 5. Total Likes has been growing
